# %% [markdown]
# # Module 3 Final Project:

# %% [markdown]
# -  Student Names: Kenny Oh & Moses Lin
# -  Student Pace: Full Time
# -  Schedule Project Review Date/Time: 8/21/2020
# -  Instructor Name: Sean Abu Wilson
#
# Dataset from: https://catalog.data.gov/dataset/terry-stops

# %% [markdown]
# # Importing Data and Looking at Dataset

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import sqlite3 
import matplotlib.pyplot as plt
import itertools
import warnings; warnings.simplefilter('ignore')

from pandas import set_option
plt.style.use('ggplot')
pd.set_option('display.max_columns', 1000)
# %matplotlib inline 

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks
from collections import Counter
from IPython.display import Image  
import pydotplus

from scipy.stats import randint

from sklearn import metrics

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import accuracy_score, f1_score, recall_score
from sklearn.metrics import make_scorer, accuracy_score 
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc

from sklearn.neighbors import KNeighborsClassifier

from sklearn.tree import DecisionTreeClassifier 
from sklearn.tree import export_graphviz 

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV  
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import KFold 

from sklearn.linear_model import LogisticRegression 

from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectFromModel

from sklearn.pipeline import Pipeline 

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.utils import resample

# %%
df = pd.read_csv('Terry_Stops.csv')
df.head(3)
# Out:
#   Subject Age Group  Subject ID     GO / SC Num  Terry Stop ID  \
# 0                 -          -1  20140000120677          92317
# 1                 -          -1  20150000001463          28806
# 2                 -          -1  20150000001516          29599
#
#   Stop Resolution Weapon Type Officer ID  Officer YOB Officer Gender  \
# 0          Arrest        None     7500           1984              M
# 1   Field Contact        None     5670           1965              M
# 2   Field Contact        None     4844           1961              M
#
#                 Officer Race Subject Perceived Race Subject Perceived Gender  \
# 0  Black or African American                  Asian                     Male
# 1                      White                      -                        -
# 2                      White                  White                     Male
#
#          Reported Date Reported Time Initial Call Type Final Call Type  \
# 0  2015-10-16T00:00:00      11:32:00                 -               -
# 1  2015-03-19T00:00:00      07:59:00                 -               -
# 2  2015-03-21T00:00:00      19:12:00                 -               -
#
#   Call Type             Officer Squad Arrest Flag Frisk Flag Precinct  Sector  \
# 0         -  SOUTH PCT 1ST W - ROBERT           N          N    South  O
# 1         -                       NaN           N          N        -       -
# 2         -                       NaN           N          -        -       -
#
#      Beat
# 0  O2
# 1       -
# 2       -

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43496 entries, 0 to 43495
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject Age Group         43496 non-null  object
#  1   Subject ID                43496 non-null  int64
#  2   GO / SC Num               43496 non-null  int64
#  3   Terry Stop ID             43496 non-null  int64
#  4   Stop Resolution           43496 non-null  object
#  5   Weapon Type               43496 non-null  object
#  6   Officer ID                43496 non-null  object
#  7   Officer YOB               43496 non-null  int64
#  8   Officer Gender            43496 non-null  object
#  9   Officer Race              43496 non-null  object
#  10  Subject Perceived Race    43496 non-null  object
#  11  Subject Perceived Gender  43496 non-null  object
#  12  Reported Date             43496 non-null  object
#  13  Reported Time             43496 non-null  object
#  14  Initial Call Type         43496 non-null  object
#  15  Final Call Type           43496 non-null  object
#  16  Call Type                 43496 non-null  object
#  17  Officer Squad             42952 non-null  object
#  18  Arrest Flag               43496 non-null  object
#  19  Frisk Flag                43496 non-null  object
#  20  Precinct                  43496 non-null  object
#  21  Sector                    43496 non-null  object
#  22  Beat                      43496 non-null  object
# dtypes: int64(4), object(19)
# memory usage: 7.6+ MB

# %% [markdown]
# # Cleaning Dataset

# %%
# Dropping columns that provide no real information to us, or is too difficult to work with.
# This is one is including specifics of Seattle Police

# Subject ID, GO/SC Num, Terry Stop ID, Officer ID are not relevant at all
# Call Types has too many null values
# Initial Call Type and Final Call Type have too many different values.

df.drop(columns=['Subject ID', 'GO / SC Num', 'Terry Stop ID', 'Officer ID', 'Call Type', 'Initial Call Type', 'Final Call Type'], inplace=True)
df

# %%
# Dropping columns that provide no real information to us, or is too difficult to work with.
# This is one is not including specifics of Seattle Police

# Subject ID, GO/SC Num, Terry Stop ID, Officer ID are not relevant at all
# Call Types has too many null values
# Initial Call Type and Final Call Type have too many different values.
# Officer Squad, Precinct, Sector, Beat are too specific and is similar to ID in not being too relevant

df.drop(columns=['Subject ID', 'GO / SC Num', 'Terry Stop ID', 'Officer ID', 'Call Type', 'Initial Call Type', 'Final Call Type', 'Officer Squad', 'Precinct', 'Sector', 'Beat'], inplace=True)
df
# Out:
#       Subject Age Group Stop Resolution                        Weapon Type  \
# 0                     -          Arrest                               None
# 1                     -   Field Contact                               None
# 2                     -   Field Contact                               None
# 3                     -   Field Contact                               None
# 4                     -   Field Contact                               None
# ...                 ...             ...                                ...
# 43491      56 and Above          Arrest                                  -
# 43492      56 and Above   Field Contact                                  -
# 43493      56 and Above          Arrest                            Firearm
# 43494      56 and Above   Field Contact  Knife/Cutting/Stabbing Instrument
# 43495      56 and Above  Offense Report                                  -
#
#        Officer YOB Officer Gender               Officer Race  \
# 0             1984              M  Black or African American
# 1             1965              M                      White
# 2             1961              M                      White
# 3             1963              M                      White
# 4             1977              M                      White
# ...            ...            ...                        ...
# 43491         1992              M                      White
# 43492         1995              F         Hispanic or Latino
# 43493         1994              M                      Asian
# 43494         1983              M          Two or More Races
# 43495         1986              M                      White
#
#           Subject Perceived Race Subject Perceived Gender  \
# 0                          Asian                     Male
# 1                              -                        -
# 2                          White                     Male
# 3                              -                        -
# 4      Black or African American                     Male
# ...                          ...                      ...
# 43491                      White                     Male
# 43492                      White                     Male
# 43493  Black or African American                     Male
# 43494  Black or African American                     Male
# 43495                      Asian                     Male
#
#              Reported Date Reported Time Arrest Flag Frisk Flag
# 0      2015-10-16T00:00:00      11:32:00           N          N
# 1      2015-03-19T00:00:00      07:59:00           N          N
# 2      2015-03-21T00:00:00      19:12:00           N          -
# 3      2015-04-01T00:00:00      04:55:00           N          N
# 4      2015-04-03T00:00:00      00:41:00           N          N
# ...                    ...           ...         ...        ...
# 43491  2020-07-12T00:00:00      08:20:33           Y          N
# 43492  2020-07-21T00:00:00      00:41:13           N          N
# 43493  2020-07-26T00:00:00      20:37:41           Y          Y
# 43494  2020-08-04T00:00:00      23:07:39           N          Y
# 43495  2020-08-09T00:00:00      12:02:39           N          N
#
# [43496 rows x 12 columns]

# %%
# Renaming columns so that they will be easier to work with.
# This is one is including specifics of Seattle Police

df.columns = ['subject_age_group', 'stop_resolution', 'weapon_type', 'officer_yob', 'officer_gender', 'officer_race', 'subject_perceived_race', 'subject_perceived_gender','reported_date', 'reported_time', 'officer_squad', 'arrest_flag', 'frisk_flag', 'precinct', 'sector', 'beat']
df

# %%
# Renaming columns so that they will be easier to work with.
# This is one is not including specifics of Seattle Police

df.columns = ['subject_age_group', 'stop_resolution', 'weapon_type', 'officer_yob', 'officer_gender', 'officer_race', 'subject_perceived_race', 'subject_perceived_gender','reported_date', 'reported_time', 'arrest_flag', 'frisk_flag']
df
# Out:
#       subject_age_group stop_resolution                        weapon_type  \
# 0                     -          Arrest                               None
# 1                     -   Field Contact                               None
# 2                     -   Field Contact                               None
# 3                     -   Field Contact                               None
# 4                     -   Field Contact                               None
# ...                 ...             ...                                ...
# 43491      56 and Above          Arrest                                  -
# 43492      56 and Above   Field Contact                                  -
# 43493      56 and Above          Arrest                            Firearm
# 43494      56 and Above   Field Contact  Knife/Cutting/Stabbing Instrument
# 43495      56 and Above  Offense Report                                  -
#
#        officer_yob officer_gender               officer_race  \
# 0             1984              M  Black or African American
# 1             1965              M                      White
# 2             1961              M                      White
# 3             1963              M                      White
# 4             1977              M                      White
# ...            ...            ...                        ...
# 43491         1992              M                      White
# 43492         1995              F         Hispanic or Latino
# 43493         1994              M                      Asian
# 43494         1983              M          Two or More Races
# 43495         1986              M                      White
#
#           subject_perceived_race subject_perceived_gender  \
# 0                          Asian                     Male
# 1                              -                        -
# 2                          White                     Male
# 3                              -                        -
# 4      Black or African American                     Male
# ...                          ...                      ...
# 43491                      White                     Male
# 43492                      White                     Male
# 43493  Black or African American                     Male
# 43494  Black or African American                     Male
# 43495                      Asian                     Male
#
#              reported_date reported_time arrest_flag frisk_flag
# 0      2015-10-16T00:00:00      11:32:00           N          N
# 1      2015-03-19T00:00:00      07:59:00           N          N
# 2      2015-03-21T00:00:00      19:12:00           N          -
# 3      2015-04-01T00:00:00      04:55:00           N          N
# 4      2015-04-03T00:00:00      00:41:00           N          N
# ...                    ...           ...         ...        ...
# 43491  2020-07-12T00:00:00      08:20:33           Y          N
# 43492  2020-07-21T00:00:00      00:41:13           N          N
# 43493  2020-07-26T00:00:00      20:37:41           Y          Y
# 43494  2020-08-04T00:00:00      23:07:39           N          Y
# 43495  2020-08-09T00:00:00      12:02:39           N          N
#
# [43496 rows x 12 columns]

# %%
# Seeing what values we have for each column to work with.

#df['subject_age_group'].value_counts()
#df['stop_resolution'].value_counts()
#df['weapon_type'].value_counts()
#df['officer_yob'].value_counts()
#df['officer_race'].value_counts()
#df['subject_perceived_race'].value_counts()
#df['subject_perceived_gender'].value_counts()
#df['arrest_flag'].value_counts()
#df['frisk_flag'].value_counts()
#df['officer_squad'].value_counts()
#df['precinct'].value_counts()
#df['sector'].value_counts()
#df['beat'].value_counts()

# %%
# 1371 Entries without an age group. Will remove.

df = df[df.subject_age_group != '-']
df
# Out:
#       subject_age_group stop_resolution                        weapon_type  \
# 128             36 - 45  Offense Report                               None
# 130        56 and Above   Field Contact                                  -
# 175             36 - 45  Offense Report                               None
# 200        56 and Above          Arrest                                  -
# 703        56 and Above   Field Contact                                  -
# ...                 ...             ...                                ...
# 43491      56 and Above          Arrest                                  -
# 43492      56 and Above   Field Contact                                  -
# 43493      56 and Above          Arrest                            Firearm
# 43494      56 and Above   Field Contact  Knife/Cutting/Stabbing Instrument
# 43495      56 and Above  Offense Report                                  -
#
#        officer_yob officer_gender        officer_race  \
# 128           1985              M               White
# 130           1995              M               White
# 175           1992              M               White
# 200           1989              M               White
# 703           1972              M               White
# ...            ...            ...                 ...
# 43491         1992              M               White
# 43492         1995              F  Hispanic or Latino
# 43493         1994              M               Asian
# 43494         1983              M   Two or More Races
# 43495         1986              M               White
#
#           subject_perceived_race subject_perceived_gender  \
# 128                      Unknown                     Male
# 130                        White                     Male
# 175                        White                   Female
# 200                        Asian                     Male
# 703                        White                     Male
# ...                          ...                      ...
# 43491                      White                     Male
# 43492                      White                     Male
# 43493  Black or African American                     Male
# 43494  Black or African American                     Male
# 43495                      Asian                     Male
#
#              reported_date reported_time arrest_flag frisk_flag
# 128    2018-09-23T00:00:00      18:35:00           N          N
# 130    2019-12-11T00:00:00      01:25:31           N          N
# 175    2018-09-24T00:00:00      03:21:00           N          N
# 200    2019-12-21T00:00:00      21:02:58           Y          Y
# 703    2019-12-25T00:00:00      11:42:08           N          Y
# ...                    ...           ...         ...        ...
# 43491  2020-07-12T00:00:00      08:20:33           Y          N
# 43492  2020-07-21T00:00:00      00:41:13           N          N
# 43493  2020-07-26T00:00:00      20:37:41           Y          Y
# 43494  2020-08-04T00:00:00      23:07:39           N          Y
# 43495  2020-08-09T00:00:00      12:02:39           N          N
#
# [42125 rows x 12 columns]

# %%
# Will lose ~8091 entries here, but there was nothing recorded. Have to remove.

df = df[df.weapon_type != '-']
df
# Out:
#       subject_age_group stop_resolution                        weapon_type  \
# 128             36 - 45  Offense Report                               None
# 175             36 - 45  Offense Report                               None
# 1376             1 - 17          Arrest                               None
# 1377             1 - 17   Field Contact                               None
# 1378             1 - 17   Field Contact                               None
# ...                 ...             ...                                ...
# 43475      56 and Above          Arrest  Knife/Cutting/Stabbing Instrument
# 43478      56 and Above          Arrest  Knife/Cutting/Stabbing Instrument
# 43489      56 and Above   Field Contact  Knife/Cutting/Stabbing Instrument
# 43493      56 and Above          Arrest                            Firearm
# 43494      56 and Above   Field Contact  Knife/Cutting/Stabbing Instrument
#
#        officer_yob officer_gender               officer_race  \
# 128           1985              M                      White
# 175           1992              M                      White
# 1376          1992              M                      White
# 1377          1988              F              Not Specified
# 1378          1977              M                      White
# ...            ...            ...                        ...
# 43475         1989              M          Two or More Races
# 43478         1976              M                      White
# 43489         1988              M  Black or African American
# 43493         1994              M                      Asian
# 43494         1983              M          Two or More Races
#
#                  subject_perceived_race subject_perceived_gender  \
# 128                             Unknown                     Male
# 175                               White                   Female
# 1376   American Indian or Alaska Native                     Male
# 1377                            Unknown                     Male
# 1378          Black or African American                     Male
# ...                                 ...                      ...
# 43475                             White                     Male
# 43478                             White                     Male
# 43489         Black or African American                     Male
# 43493         Black or African American                     Male
# 43494         Black or African American                     Male
#
#              reported_date reported_time arrest_flag frisk_flag
# 128    2018-09-23T00:00:00      18:35:00           N          N
# 175    2018-09-24T00:00:00      03:21:00           N          N
# 1376   2015-09-13T00:00:00      00:31:00           N          Y
# 1377   2015-04-19T00:00:00      03:02:00           N          Y
# 1378   2015-04-19T00:00:00      05:51:00           N          -
# ...                    ...           ...         ...        ...
# 43475  2020-04-09T00:00:00      10:55:21           Y          Y
# 43478  2020-04-23T00:00:00      00:42:59           Y          Y
# 43489  2020-07-09T00:00:00      19:11:09           N          Y
# 43493  2020-07-26T00:00:00      20:37:41           Y          Y
# 43494  2020-08-04T00:00:00      23:07:39           N          Y
#
# [34034 rows x 12 columns]

# %%
# Will classify weapons into more manageable categories, as some are redundant.

df['weapon_type'] = df['weapon_type'].replace(['Handgun', 'Firearm Other', 'Firearm (unk type)', 'Other Firearm', 'Rifle', 'Shotgun', 'Automatic Handgun'], 'Firearm')
df['weapon_type'] = df['weapon_type'].replace(['Lethal Cutting Instrument', 'Knife/Cutting/Stabbing Instrument', 'Blunt Object/Striking Implement', 'Club, Blackjack, Brass Knuckles', 'Club', 'Blackjack', 'Brass Knuckles'], 'Melee Weapon')
df['weapon_type'] = df['weapon_type'].replace(['None/Not Applicable'], 'None')
df['weapon_type'] = df['weapon_type'].replace(['Mace/Pepper Spray', 'Taser/Stun Gun', 'Fire/Incendiary Device'], 'Other')
df['weapon_type'].value_counts()
# Out:
# None            31607
# Melee Weapon     1990
# Firearm           415
# Other              22
# Name: weapon_type, dtype: int64

# %%
# Strange to not know own officer's race. Will remove 7 entries.

df = df[df.officer_race != 'Unknown']
df
# Out:
#       subject_age_group stop_resolution   weapon_type  officer_yob  \
# 128             36 - 45  Offense Report          None         1985
# 175             36 - 45  Offense Report          None         1992
# 1376             1 - 17          Arrest          None         1992
# 1377             1 - 17   Field Contact          None         1988
# 1378             1 - 17   Field Contact          None         1977
# ...                 ...             ...           ...          ...
# 43475      56 and Above          Arrest  Melee Weapon         1989
# 43478      56 and Above          Arrest  Melee Weapon         1976
# 43489      56 and Above   Field Contact  Melee Weapon         1988
# 43493      56 and Above          Arrest       Firearm         1994
# 43494      56 and Above   Field Contact  Melee Weapon         1983
#
#       officer_gender               officer_race  \
# 128                M                      White
# 175                M                      White
# 1376               M                      White
# 1377               F              Not Specified
# 1378               M                      White
# ...              ...                        ...
# 43475              M          Two or More Races
# 43478              M                      White
# 43489              M  Black or African American
# 43493              M                      Asian
# 43494              M          Two or More Races
#
#                  subject_perceived_race subject_perceived_gender  \
# 128                             Unknown                     Male
# 175                               White                   Female
# 1376   American Indian or Alaska Native                     Male
# 1377                            Unknown                     Male
# 1378          Black or African American                     Male
# ...                                 ...                      ...
# 43475                             White                     Male
# 43478                             White                     Male
# 43489         Black or African American                     Male
# 43493         Black or African American                     Male
# 43494         Black or African American                     Male
#
#              reported_date reported_time arrest_flag frisk_flag
# 128    2018-09-23T00:00:00      18:35:00           N          N
# 175    2018-09-24T00:00:00      03:21:00           N          N
# 1376   2015-09-13T00:00:00      00:31:00           N          Y
# 1377   2015-04-19T00:00:00      03:02:00           N          Y
# 1378   2015-04-19T00:00:00      05:51:00           N          -
# ...                    ...           ...         ...        ...
# 43475  2020-04-09T00:00:00      10:55:21           Y          Y
# 43478  2020-04-23T00:00:00      00:42:59           Y          Y
# 43489  2020-07-09T00:00:00      19:11:09           N          Y
# 43493  2020-07-26T00:00:00      20:37:41           Y          Y
# 43494  2020-08-04T00:00:00      23:07:39           N          Y
#
# [34027 rows x 12 columns]

# %%
# Removing unrecorded race entries. Losing 196 entries.

df = df[df.subject_perceived_race != '-']
df
# Out:
#       subject_age_group stop_resolution   weapon_type  officer_yob  \
# 128             36 - 45  Offense Report          None         1985
# 175             36 - 45  Offense Report          None         1992
# 1376             1 - 17          Arrest          None         1992
# 1377             1 - 17   Field Contact          None         1988
# 1378             1 - 17   Field Contact          None         1977
# ...                 ...             ...           ...          ...
# 43475      56 and Above          Arrest  Melee Weapon         1989
# 43478      56 and Above          Arrest  Melee Weapon         1976
# 43489      56 and Above   Field Contact  Melee Weapon         1988
# 43493      56 and Above          Arrest       Firearm         1994
# 43494      56 and Above   Field Contact  Melee Weapon         1983
#
#       officer_gender               officer_race  \
# 128                M                      White
# 175                M                      White
# 1376               M                      White
# 1377               F              Not Specified
# 1378               M                      White
# ...              ...                        ...
# 43475              M          Two or More Races
# 43478              M                      White
# 43489              M  Black or African American
# 43493              M                      Asian
# 43494              M          Two or More Races
#
#                  subject_perceived_race subject_perceived_gender  \
# 128                             Unknown                     Male
# 175                               White                   Female
# 1376   American Indian or Alaska Native                     Male
# 1377                            Unknown                     Male
# 1378          Black or African American                     Male
# ...                                 ...                      ...
# 43475                             White                     Male
# 43478                             White                     Male
# 43489         Black or African American                     Male
# 43493         Black or African American                     Male
# 43494         Black or African American                     Male
#
#              reported_date reported_time arrest_flag frisk_flag
# 128    2018-09-23T00:00:00      18:35:00           N          N
# 175    2018-09-24T00:00:00      03:21:00           N          N
# 1376   2015-09-13T00:00:00      00:31:00           N          Y
# 1377   2015-04-19T00:00:00      03:02:00           N          Y
# 1378   2015-04-19T00:00:00      05:51:00           N          -
# ...                    ...           ...         ...        ...
# 43475  2020-04-09T00:00:00      10:55:21           Y          Y
# 43478  2020-04-23T00:00:00      00:42:59           Y          Y
# 43489  2020-07-09T00:00:00      19:11:09           N          Y
# 43493  2020-07-26T00:00:00      20:37:41           Y          Y
# 43494  2020-08-04T00:00:00      23:07:39           N          Y
#
# [33831 rows x 12 columns]

# %%
# Combining three categories since they are similar in terms of what they mean in this scenario

df['subject_perceived_gender'] = df['subject_perceived_gender'].replace(['-', 'Unknown', 'Gender Diverse'], 'Unable to Determine') 
df
# Out:
#       subject_age_group stop_resolution   weapon_type  officer_yob  \
# 128             36 - 45  Offense Report          None         1985
# 175             36 - 45  Offense Report          None         1992
# 1376             1 - 17          Arrest          None         1992
# 1377             1 - 17   Field Contact          None         1988
# 1378             1 - 17   Field Contact          None         1977
# ...                 ...             ...           ...          ...
# 43475      56 and Above          Arrest  Melee Weapon         1989
# 43478      56 and Above          Arrest  Melee Weapon         1976
# 43489      56 and Above   Field Contact  Melee Weapon         1988
# 43493      56 and Above          Arrest       Firearm         1994
# 43494      56 and Above   Field Contact  Melee Weapon         1983
#
#       officer_gender               officer_race  \
# 128                M                      White
# 175                M                      White
# 1376               M                      White
# 1377               F              Not Specified
# 1378               M                      White
# ...              ...                        ...
# 43475              M          Two or More Races
# 43478              M                      White
# 43489              M  Black or African American
# 43493              M                      Asian
# 43494              M          Two or More Races
#
#                  subject_perceived_race subject_perceived_gender  \
# 128                             Unknown                     Male
# 175                               White                   Female
# 1376   American Indian or Alaska Native                     Male
# 1377                            Unknown                     Male
# 1378          Black or African American                     Male
# ...                                 ...                      ...
# 43475                             White                     Male
# 43478                             White                     Male
# 43489         Black or African American                     Male
# 43493         Black or African American                     Male
# 43494         Black or African American                     Male
#
#              reported_date reported_time arrest_flag frisk_flag
# 128    2018-09-23T00:00:00      18:35:00           N          N
# 175    2018-09-24T00:00:00      03:21:00           N          N
# 1376   2015-09-13T00:00:00      00:31:00           N          Y
# 1377   2015-04-19T00:00:00      03:02:00           N          Y
# 1378   2015-04-19T00:00:00      05:51:00           N          -
# ...                    ...           ...         ...        ...
# 43475  2020-04-09T00:00:00      10:55:21           Y          Y
# 43478  2020-04-23T00:00:00      00:42:59           Y          Y
# 43489  2020-07-09T00:00:00      19:11:09           N          Y
# 43493  2020-07-26T00:00:00      20:37:41           Y          Y
# 43494  2020-08-04T00:00:00      23:07:39           N          Y
#
# [33831 rows x 12 columns]

# %%
# Removing 390 entries that are not labeled.

df = df[df.frisk_flag != '-']
df
# Out:
#       subject_age_group stop_resolution   weapon_type  officer_yob  \
# 128             36 - 45  Offense Report          None         1985
# 175             36 - 45  Offense Report          None         1992
# 1376             1 - 17          Arrest          None         1992
# 1377             1 - 17   Field Contact          None         1988
# 1380             1 - 17   Field Contact          None         1988
# ...                 ...             ...           ...          ...
# 43475      56 and Above          Arrest  Melee Weapon         1989
# 43478      56 and Above          Arrest  Melee Weapon         1976
# 43489      56 and Above   Field Contact  Melee Weapon         1988
# 43493      56 and Above          Arrest       Firearm         1994
# 43494      56 and Above   Field Contact  Melee Weapon         1983
#
#       officer_gender               officer_race  \
# 128                M                      White
# 175                M                      White
# 1376               M                      White
# 1377               F              Not Specified
# 1380               M                      White
# ...              ...                        ...
# 43475              M          Two or More Races
# 43478              M                      White
# 43489              M  Black or African American
# 43493              M                      Asian
# 43494              M          Two or More Races
#
#                  subject_perceived_race subject_perceived_gender  \
# 128                             Unknown                     Male
# 175                               White                   Female
# 1376   American Indian or Alaska Native                     Male
# 1377                            Unknown                     Male
# 1380                              White                     Male
# ...                                 ...                      ...
# 43475                             White                     Male
# 43478                             White                     Male
# 43489         Black or African American                     Male
# 43493         Black or African American                     Male
# 43494         Black or African American                     Male
#
#              reported_date reported_time arrest_flag frisk_flag
# 128    2018-09-23T00:00:00      18:35:00           N          N
# 175    2018-09-24T00:00:00      03:21:00           N          N
# 1376   2015-09-13T00:00:00      00:31:00           N          Y
# 1377   2015-04-19T00:00:00      03:02:00           N          Y
# 1380   2015-04-20T00:00:00      22:40:00           N          N
# ...                    ...           ...         ...        ...
# 43475  2020-04-09T00:00:00      10:55:21           Y          Y
# 43478  2020-04-23T00:00:00      00:42:59           Y          Y
# 43489  2020-07-09T00:00:00      19:11:09           N          Y
# 43493  2020-07-26T00:00:00      20:37:41           Y          Y
# 43494  2020-08-04T00:00:00      23:07:39           N          Y
#
# [33441 rows x 12 columns]

# %%
# Checking the number of arrests and no arrests.

df['arrest_flag'] = df['arrest_flag'].replace(['Y'], 1)
df['arrest_flag'] = df['arrest_flag'].replace(['N'], 0)
df['arrest_flag'].value_counts()
# Out:
# 0    33203
# 1      238
# Name: arrest_flag, dtype: int64

# %%
# Only run this if using specifics of Seattle Police
# Remove values that are not useable.

df = df[df.officer_squad != '-']
df = df[df.precinct != '-']
df = df[df.precinct != 'Unknown']
df = df[df.sector != '-']
df = df[df.beat != '-']
df

# %% [markdown]
# # Feature Engineering

# %%
# Changing reported_time into useable values.

# Morning = 5am - 12pm
# Afternoon = 1pm to 5pm
# Evening = 6pm to 9pm
# Night = 10pm to 4am

from datetime import datetime
df['reported_hour'] = df['reported_time'].apply(pd.to_datetime).dt.hour
df.drop(['reported_time'], axis=1, inplace=True)
df.head(3)
# Out:
#      subject_age_group stop_resolution weapon_type  officer_yob  \
# 128            36 - 45  Offense Report        None         1985
# 175            36 - 45  Offense Report        None         1992
# 1376            1 - 17          Arrest        None         1992
#
#      officer_gender officer_race            subject_perceived_race  \
# 128               M        White                           Unknown
# 175               M        White                             White
# 1376              M        White  American Indian or Alaska Native
#
#      subject_perceived_gender        reported_date  arrest_flag frisk_flag  \
# 128                      Male  2018-09-23T00:00:00            0          N
# 175                    Female  2018-09-24T00:00:00            0          N
# 1376                     Male  2015-09-13T00:00:00            0          Y
#
#       reported_hour
# 128              18
# 175               3
# 1376              0

# %%
df['reported_hour'] = df['reported_hour'].replace([5, 6, 7, 8, 9, 10, 11, 12], 'morning')
df['reported_hour'] = df['reported_hour'].replace([13, 14, 15, 16, 17], 'afternoon')
df['reported_hour'] = df['reported_hour'].replace([18, 19, 20, 21], 'evening')
df['reported_hour'] = df['reported_hour'].replace([22, 23, 0, 1, 2, 3, 4], 'night')
df['reported_hour'].value_counts()
# Out:
# night        10743
# morning       8571
# afternoon     7908
# evening       6219
# Name: reported_hour, dtype: int64

# %%
df['reported_date'] = df['reported_date'].str.slice(0, 4, 1)
df
# Out:
#       subject_age_group stop_resolution   weapon_type  officer_yob  \
# 128             36 - 45  Offense Report          None         1985
# 175             36 - 45  Offense Report          None         1992
# 1376             1 - 17          Arrest          None         1992
# 1377             1 - 17   Field Contact          None         1988
# 1380             1 - 17   Field Contact          None         1988
# ...                 ...             ...           ...          ...
# 43475      56 and Above          Arrest  Melee Weapon         1989
# 43478      56 and Above          Arrest  Melee Weapon         1976
# 43489      56 and Above   Field Contact  Melee Weapon         1988
# 43493      56 and Above          Arrest       Firearm         1994
# 43494      56 and Above   Field Contact  Melee Weapon         1983
#
#       officer_gender               officer_race  \
# 128                M                      White
# 175                M                      White
# 1376               M                      White
# 1377               F              Not Specified
# 1380               M                      White
# ...              ...                        ...
# 43475              M          Two or More Races
# 43478              M                      White
# 43489              M  Black or African American
# 43493              M                      Asian
# 43494              M          Two or More Races
#
#                  subject_perceived_race subject_perceived_gender  \
# 128                             Unknown                     Male
# 175                               White                   Female
# 1376   American Indian or Alaska Native                     Male
# 1377                            Unknown                     Male
# 1380                              White                     Male
# ...                                 ...                      ...
# 43475                             White                     Male
# 43478                             White                     Male
# 43489         Black or African American                     Male
# 43493         Black or African American                     Male
# 43494         Black or African American                     Male
#
#       reported_date  arrest_flag frisk_flag reported_hour
# 128            2018            0          N       evening
# 175            2018            0          N         night
# 1376           2015            0          Y         night
# 1377           2015            0          Y         night
# 1380           2015            0          N         night
# ...             ...          ...        ...           ...
# 43475          2020            1          Y       morning
# 43478          2020            1          Y         night
# 43489          2020            0          Y       evening
# 43493          2020            1          Y       evening
# 43494          2020            0          Y         night
#
# [33441 rows x 12 columns]

# %%
# reported_date is a str as of now

df['reported_date'] = df['reported_date'].astype(int)

# %%
df['officer_age'] = df['reported_date'] - df['officer_yob']
df.drop(['officer_yob', 'reported_date'], axis=1, inplace=True)
df.head()
# Out:
#      subject_age_group stop_resolution weapon_type officer_gender  \
# 128            36 - 45  Offense Report        None              M
# 175            36 - 45  Offense Report        None              M
# 1376            1 - 17          Arrest        None              M
# 1377            1 - 17   Field Contact        None              F
# 1380            1 - 17   Field Contact        None              M
#
#        officer_race            subject_perceived_race  \
# 128           White                           Unknown
# 175           White                             White
# 1376          White  American Indian or Alaska Native
# 1377  Not Specified                           Unknown
# 1380          White                             White
#
#      subject_perceived_gender  arrest_flag frisk_flag reported_hour  \
# 128                      Male            0          N       evening
# 175                    Female            0          N         night
# 1376                     Male            0          Y         night
# 1377                     Male            0          Y         night
# 1380                     Male            0          N         night
#
#       officer_age
# 128            33
# 175            26
# 1376           23
# 1377           27
# 1380           27

# %%
# Generate Dummy Variable for literally everything
# This is one is including specifics of Seattle Police

dummyf =  pd.get_dummies(df, columns=['subject_age_group', 'stop_resolution', 'weapon_type', 
'officer_gender', 'officer_race', 'subject_perceived_race', 'subject_perceived_gender', 'officer_squad', 'frisk_flag', 'precinct', 'sector', 'beat', 
'reported_hour'])

dummyf

# %%
# Generate Dummy Variable for literally everything
# This is one is not including specifics of Seattle Police

dummyf =  pd.get_dummies(df, columns=['subject_age_group', 'stop_resolution', 'weapon_type', 
'officer_gender', 'officer_race', 'subject_perceived_race', 'subject_perceived_gender', 'frisk_flag', 
'reported_hour'])

dummyf
# Out:
#        arrest_flag  officer_age  subject_age_group_1 - 17  \
# 128              0           33                         0
# 175              0           26                         0
# 1376             0           23                         1
# 1377             0           27                         1
# 1380             0           27                         1
# ...            ...          ...                       ...
# 43475            1           31                         0
# 43478            1           44                         0
# 43489            0           32                         0
# 43493            1           26                         0
# 43494            0           37                         0
#
#        subject_age_group_18 - 25  subject_age_group_26 - 35  \
# 128                            0                          0
# 175                            0                          0
# 1376                           0                          0
# 1377                           0                          0
# 1380                           0                          0
# ...                          ...                        ...
# 43475                          0                          0
# 43478                          0                          0
# 43489                          0                          0
# 43493                          0                          0
# 43494                          0                          0
#
#        subject_age_group_36 - 45  subject_age_group_46 - 55  \
# 128                            1                          0
# 175                            1                          0
# 1376                           0                          0
# 1377                           0                          0
# 1380                           0                          0
# ...                          ...                        ...
# 43475                          0                          0
# 43478                          0                          0
# 43489                          0                          0
# 43493                          0                          0
# 43494                          0                          0
#
#        subject_age_group_56 and Above  stop_resolution_Arrest  \
# 128                                 0                       0
# 175                                 0                       0
# 1376                                0                       1
# 1377                                0                       0
# 1380                                0                       0
# ...                               ...                     ...
# 43475                               1                       1
# 43478                               1                       1
# 43489                               1                       0
# 43493                               1                       1
# 43494                               1                       0
#
#        stop_resolution_Citation / Infraction  stop_resolution_Field Contact  \
# 128                                        0                              0
# 175                                        0                              0
# 1376                                       0                              0
# 1377                                       0                              1
# 1380                                       0                              1
# ...                                      ...                            ...
# 43475                                      0                              0
# 43478                                      0                              0
# 43489                                      0                              1
# 43493                                      0                              0
# 43494                                      0                              1
#
#        stop_resolution_Offense Report  \
# 128                                 1
# 175                                 1
# 1376                                0
# 1377                                0
# 1380                                0
# ...                               ...
# 43475                               0
# 43478                               0
# 43489                               0
# 43493                               0
# 43494                               0
#
#        stop_resolution_Referred for Prosecution  weapon_type_Firearm  \
# 128                                           0                    0
# 175                                           0                    0
# 1376                                          0                    0
# 1377                                          0                    0
# 1380                                          0                    0
# ...                                         ...                  ...
# 43475                                         0                    0
# 43478                                         0                    0
# 43489                                         0                    0
# 43493                                         0                    1
# 43494                                         0                    0
#
#        weapon_type_Melee Weapon  weapon_type_None  weapon_type_Other  \
# 128                           0                 1                  0
# 175                           0                 1                  0
# 1376                          0                 1                  0
# 1377                          0                 1                  0
# 1380                          0                 1                  0
# ...                         ...               ...                ...
# 43475                         1                 0                  0
# 43478                         1                 0                  0
# 43489                         1                 0                  0
# 43493                         0                 0                  0
# 43494                         1                 0                  0
#
#        officer_gender_F  officer_gender_M  \
# 128                   0                 1
# 175                   0                 1
# 1376                  0                 1
# 1377                  1                 0
# 1380                  0                 1
# ...                 ...               ...
# 43475                 0                 1
# 43478                 0                 1
# 43489                 0                 1
# 43493                 0                 1
# 43494                 0                 1
#
#        officer_race_American Indian/Alaska Native  officer_race_Asian  \
# 128                                             0                   0
# 175                                             0                   0
# 1376                                            0                   0
# 1377                                            0                   0
# 1380                                            0                   0
# ...                                           ...                 ...
# 43475                                           0                   0
# 43478                                           0                   0
# 43489                                           0                   0
# 43493                                           0                   1
# 43494                                           0                   0
#
#        officer_race_Black or African American  \
# 128                                         0
# 175                                         0
# 1376                                        0
# 1377                                        0
# 1380                                        0
# ...                                       ...
# 43475                                       0
# 43478                                       0
# 43489                                       1
# 43493                                       0
# 43494                                       0
#
#        officer_race_Hispanic or Latino  \
# 128                                  0
# 175                                  0
# 1376                                 0
# 1377                                 0
# 1380                                 0
# ...                                ...
# 43475                                0
# 43478                                0
# 43489                                0
# 43493                                0
# 43494                                0
#
#        officer_race_Nat Hawaiian/Oth Pac Islander  officer_race_Not Specified  \
# 128                                             0                           0
# 175                                             0                           0
# 1376                                            0                           0
# 1377                                            0                           1
# 1380                                            0                           0
# ...                                           ...                         ...
# 43475                                           0                           0
# 43478                                           0                           0
# 43489                                           0                           0
# 43493                                           0                           0
# 43494                                           0                           0
#
#        officer_race_Two or More Races  officer_race_White  \
# 128                                 0                   1
# 175                                 0                   1
# 1376                                0                   1
# 1377                                0                   0
# 1380                                0                   1
# ...                               ...                 ...
# 43475                               1                   0
# 43478                               0                   1
# 43489                               0                   0
# 43493                               0                   0
# 43494                               1                   0
#
#        subject_perceived_race_American Indian or Alaska Native  \
# 128                                                    0
# 175                                                    0
# 1376                                                   1
# 1377                                                   0
# 1380                                                   0
# ...                                                  ...
# 43475                                                  0
# 43478                                                  0
# 43489                                                  0
# 43493                                                  0
# 43494                                                  0
#
#        subject_perceived_race_Asian  \
# 128                               0
# 175                               0
# 1376                              0
# 1377                              0
# 1380                              0
# ...                             ...
# 43475                             0
# 43478                             0
# 43489                             0
# 43493                             0
# 43494                             0
#
#        subject_perceived_race_Black or African American  \
# 128                                                   0
# 175                                                   0
# 1376                                                  0
# 1377                                                  0
# 1380                                                  0
# ...                                                 ...
# 43475                                                 0
# 43478                                                 0
# 43489                                                 1
# 43493                                                 1
# 43494                                                 1
#
#        subject_perceived_race_Hispanic  subject_perceived_race_Multi-Racial  \
# 128                                  0                                    0
# 175                                  0                                    0
# 1376                                 0                                    0
# 1377                                 0                                    0
# 1380                                 0                                    0
# ...                                ...                                  ...
# 43475                                0                                    0
# 43478                                0                                    0
# 43489                                0                                    0
# 43493                                0                                    0
# 43494                                0                                    0
#
#        subject_perceived_race_Native Hawaiian or Other Pacific Islander  \
# 128                                                    0
# 175                                                    0
# 1376                                                   0
# 1377                                                   0
# 1380                                                   0
# ...                                                  ...
# 43475                                                  0
# 43478                                                  0
# 43489                                                  0
# 43493                                                  0
# 43494                                                  0
#
#        subject_perceived_race_Other  subject_perceived_race_Unknown  \
# 128                               0                               1
# 175                               0                               0
# 1376                              0                               0
# 1377                              0                               1
# 1380                              0                               0
# ...                             ...                             ...
# 43475                             0                               0
# 43478                             0                               0
# 43489                             0                               0
# 43493                             0                               0
# 43494                             0                               0
#
#        subject_perceived_race_White  subject_perceived_gender_Female  \
# 128                               0                                0
# 175                               1                                1
# 1376                              0                                0
# 1377                              0                                0
# 1380                              1                                0
# ...                             ...                              ...
# 43475                             1                                0
# 43478                             1                                0
# 43489                             0                                0
# 43493                             0                                0
# 43494                             0                                0
#
#        subject_perceived_gender_Male  \
# 128                                1
# 175                                0
# 1376                               1
# 1377                               1
# 1380                               1
# ...                              ...
# 43475                              1
# 43478                              1
# 43489                              1
# 43493                              1
# 43494                              1
#
#        subject_perceived_gender_Unable to Determine  frisk_flag_N  \
# 128                                               0             1
# 175                                               0             1
# 1376                                              0             0
# 1377                                              0             0
# 1380                                              0             1
# ...                                             ...           ...
# 43475                                             0             0
# 43478                                             0             0
# 43489                                             0             0
# 43493                                             0             0
# 43494                                             0             0
#
#        frisk_flag_Y  reported_hour_afternoon  reported_hour_evening  \
# 128               0                        0                      1
# 175               0                        0                      0
# 1376              1                        0                      0
# 1377              1                        0                      0
# 1380              0                        0                      0
# ...             ...                      ...                    ...
# 43475             1                        0                      0
# 43478             1                        0                      0
# 43489             1                        0                      1
# 43493             1                        0                      1
# 43494             1                        0                      0
#
#        reported_hour_morning  reported_hour_night
# 128                        0                    0
# 175                        0                    1
# 1376                       0                    1
# 1377                       0                    1
# 1380                       0                    1
# ...                      ...                  ...
# 43475                      1                    0
# 43478                      0                    1
# 43489                      0                    0
# 43493                      0                    0
# 43494                      0                    1
#
# [33441 rows x 45 columns]

# %% [markdown]
# # Class Imbalance

# %%
# Target = arrest_flag
# Features = everything else

target = dummyf['arrest_flag'] 
features = dummyf.drop(['arrest_flag'], axis=1)

# %%
# ~99% of the data are no arrests made.
# Need to balance the data.

target.value_counts()
# Out:
# 0    33203
# 1      238
# Name: arrest_flag, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=14,test_size=0.20)

# %%
y_test_noarrest = y_test.value_counts()[0]
y_test_arrest = y_test.value_counts()[1]

# %%
# Baseline model is created

lr_model = LogisticRegression()
lr_model.fit(X_train,y_train)

pred = lr_model.predict(X_test)

log_f1 = metrics.f1_score(y_test, pred)
log_acc = metrics.accuracy_score(y_test, pred)

print('Test F1 Score: ', log_f1)
print('Test Accuracy Score: ', log_acc)
# Out:
# Test F1 Score:  0.2068965517241379
# Test Accuracy Score:  0.9931230378232919

# %%
# ROC curve is not a good indicator for highly imbalanced data since False Positive Rate doesn't drop much when the Total Real Negatives is large.

def PlotConfusionMatrix(y_test, pred, y_test_noarrest, y_test_arrest):

    cfn_matrix = confusion_matrix(y_test, pred)
    cfn_norm_matrix = np.array([[1.0 / y_test_noarrest,1.0/y_test_noarrest],[1.0/y_test_arrest,1.0/y_test_arrest]])
    norm_cfn_matrix = cfn_matrix * cfn_norm_matrix

    fig = plt.figure(figsize=(15,5))
    ax = fig.add_subplot(1,2,1)
    sns.heatmap(cfn_matrix,cmap='coolwarm_r',linewidths=0.5,annot=True,ax=ax)
    plt.title('Confusion Matrix')
    plt.ylabel('Real Classes')
    plt.xlabel('Predicted Classes')

    ax = fig.add_subplot(1,2,2)
    sns.heatmap(norm_cfn_matrix,cmap='coolwarm_r',linewidths=0.5,annot=True,ax=ax)

    plt.title('Normalized Confusion Matrix')
    plt.ylabel('Real Classes')
    plt.xlabel('Predicted Classes')
    plt.show()
    
    print('---Classification Report---')
    print(classification_report(y_test, pred))

PlotConfusionMatrix(y_test, pred, y_test_noarrest, y_test_arrest)
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6642
#            1       0.55      0.13      0.21        47
#
#     accuracy                           0.99      6689
#    macro avg       0.77      0.56      0.60      6689
# weighted avg       0.99      0.99      0.99      6689

# %% [markdown]
# # SMOTENC

# %%
# Class balancing with SMOTE on categorical data.

from imblearn.over_sampling import SMOTENC
smote_nc = SMOTENC(categorical_features=[0, 2], random_state=0)
X_train_resampled, y_train_resampled = smote_nc.fit_resample(X_train, y_train)
print('-----------------------------------------')
print('Synthetic sample class distribution: \n')
print(pd.Series(y_train_resampled).value_counts())
# Out:
# -----------------------------------------
# Synthetic sample class distribution:
#
# 1    26561
# 0    26561
# Name: arrest_flag, dtype: int64

# %% [markdown]
# # Feature Selection

# %%
scaler = StandardScaler()
# fit the scaler to the training data
scaler.fit(X_train_resampled)
#transform the training data
X_trainFS = pd.DataFrame(data = scaler.transform(X_train_resampled), columns = features.columns)
#transform the testing dat
X_testFS = pd.DataFrame(data = scaler.transform(X_test), columns = features.columns)

# %%
from sklearn.linear_model import Lasso
from sklearn import metrics 
from sklearn.metrics import accuracy_score, f1_score, recall_score
lasso = Lasso(alpha = 0.001, normalize = False)
lasso = lasso.fit(X_train_resampled, y_train_resampled)
y_train_predFS = lasso.predict(X_train_resampled)
# y_test_pred_fs = lasso.predict(X_test_fs)

# %%
lasso.coef_
# Out:
# array([-1.38916098e-03, -0.00000000e+00, -2.93757358e-02, -3.91858037e-02,
#        -2.84966466e-02, -2.08522191e-02, -2.24690505e-02,  1.69634299e-01,
#        -0.00000000e+00,  0.00000000e+00, -1.00996185e-02, -0.00000000e+00,
#        -0.00000000e+00, -1.13193907e-03, -7.46784259e-01,  0.00000000e+00,
#        -1.71900283e-02, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -8.49086512e-03,
#        -8.97757827e-03, -1.43714362e-02, -0.00000000e+00, -0.00000000e+00,
#        -5.06699830e-03, -1.67071146e-02, -0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -3.92006259e-04, -0.00000000e+00, -5.30241201e-02,  0.00000000e+00,
#        -0.00000000e+00, -1.39484320e-02, -7.23436121e-03, -3.82742074e-03])

# %%
lasso_coef = pd.DataFrame(data=lasso.coef_).T
lasso_coef.columns = X_trainFS.columns
lasso_coef = lasso_coef.T.sort_values(by=0).T
lasso_coef.plot(kind='bar', title='Modal Coefficients', legend=True, figsize=(16,18))

# %%
lasso_coef.T
# Out:
#                                                            0
# weapon_type_None                                   -0.746784
# frisk_flag_N                                       -0.053024
# subject_age_group_26 - 35                          -0.039186
# subject_age_group_18 - 25                          -0.029376
# subject_age_group_36 - 45                          -0.028497
# subject_age_group_56 and Above                     -0.022469
# subject_age_group_46 - 55                          -0.020852
# officer_gender_F                                   -0.017190
# subject_perceived_race_Hispanic                    -0.016707
# officer_race_White                                 -0.014371
# reported_hour_evening                              -0.013948
# stop_resolution_Offense Report                     -0.010100
# officer_race_Two or More Races                     -0.008978
# officer_race_Not Specified                         -0.008491
# reported_hour_morning                              -0.007234
# subject_perceived_race_Black or African American   -0.005067
# reported_hour_night                                -0.003827
# officer_age                                        -0.001389
# weapon_type_Melee Weapon                           -0.001132
# subject_perceived_gender_Male                      -0.000392
# officer_race_American Indian/Alaska Native         -0.000000
# subject_age_group_1 - 17                           -0.000000
# reported_hour_afternoon                            -0.000000
# frisk_flag_Y                                        0.000000
# subject_perceived_gender_Unable to Determine       -0.000000
# subject_perceived_gender_Female                    -0.000000
# subject_perceived_race_White                        0.000000
# subject_perceived_race_Unknown                      0.000000
# subject_perceived_race_Other                       -0.000000
# subject_perceived_race_Native Hawaiian or Other...  0.000000
# subject_perceived_race_Multi-Racial                -0.000000
# stop_resolution_Citation / Infraction              -0.000000
# stop_resolution_Field Contact                       0.000000
# subject_perceived_race_Asian                       -0.000000
# subject_perceived_race_American Indian or Alask... -0.000000
# stop_resolution_Referred for Prosecution           -0.000000
# weapon_type_Firearm                                -0.000000
# officer_race_Nat Hawaiian/Oth Pac Islander         -0.000000
# weapon_type_Other                                   0.000000
# officer_race_Black or African American              0.000000
# officer_race_Asian                                 -0.000000
# officer_gender_M                                   -0.000000
# officer_race_Hispanic or Latino                    -0.000000
# stop_resolution_Arrest                              0.169634

# %%
# Nothing for Ridge Regression

FS = LogisticRegression(penalty='l2', C=0.01, random_state=1, class_weight='balanced')
FS = FS.fit(X_train, y_train)
y_train_predFS2 = FS.predict(X_train)

# %%
FS.coef_
# Out:
# array([[-3.05312076e-02,  3.42859535e-01, -2.05268211e-01,
#         -1.66024393e-01, -7.86413039e-02,  6.13386419e-02,
#          4.46380891e-02,  2.17340540e+00, -1.80276193e-02,
#         -9.04460000e-01, -1.12290534e+00, -1.29110075e-01,
#          9.65070688e-01,  1.23065557e+00, -2.64997082e+00,
#          4.53146921e-01, -8.00470954e-02,  7.89494541e-02,
#         -5.82595985e-02,  9.63623115e-02,  3.16381703e-01,
#          2.16220182e-01, -4.86589785e-02, -1.99692439e-01,
#         -9.52135036e-02, -2.28237318e-01, -1.20434784e-01,
#          5.02612474e-02, -5.37409850e-04, -3.35509606e-01,
#         -1.51766307e-01,  5.51810985e-02, -1.91517983e-02,
#          4.54378338e-01,  6.64815807e-02, -8.50588563e-03,
#          2.14145021e-02, -1.40062577e-02, -1.23078811e+00,
#          1.22969047e+00,  1.53470431e-01, -1.05443738e-01,
#         -1.82222616e-02, -3.09020725e-02]])

# %% [markdown]
# # Model Fitting

# %%
cleandf = dummyf[['arrest_flag', 'weapon_type_None', 'frisk_flag_N', 'subject_age_group_26 - 35', 'subject_age_group_18 - 25', 'subject_age_group_36 - 45', 'subject_age_group_56 and Above', 'subject_age_group_46 - 55', 'officer_gender_F', 'subject_perceived_race_Hispanic', 'officer_race_White', 'reported_hour_evening', 'stop_resolution_Offense Report', 'officer_race_Two or More Races', 'officer_race_Not Specified', 'reported_hour_morning', 'subject_perceived_race_Black or African American', 'reported_hour_night', 'officer_age', 'weapon_type_Melee Weapon', 'subject_perceived_gender_Male', 'stop_resolution_Arrest']]

# %%
target2 = cleandf['arrest_flag'] 
features2 = cleandf.drop(['arrest_flag'], axis=1)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(features2, target2, random_state=14,test_size=0.20)

# %%
from imblearn.over_sampling import SMOTENC
smote_nc = SMOTENC(categorical_features=[0, 2], random_state=0)
X_train_resampled2, y_train_resampled2 = smote_nc.fit_resample(X_train2, y_train2)
print('-----------------------------------------')
print('Synthetic sample class distribution: \n')
print(pd.Series(y_train_resampled).value_counts())
# Out:
# -----------------------------------------
# Synthetic sample class distribution:
#
# 1    26561
# 0    26561
# Name: arrest_flag, dtype: int64

# %% [markdown]
# # KNN

# %%
def find_best_k(X_train_resampled2, y_train_resampled2, X_test2, y_test2, min_k=1, max_k=25):
    best_k = 0
    best_score = 0.0
    for k in range(min_k, max_k+1, 2):
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train_resampled2, y_train_resampled2)
        preds = knn.predict(X_test)
        f1 = f1_score(y_test, preds)
        if f1 > best_score:
            best_k = k
            best_score = f1
    
    print("Best Value for k: {}".format(best_k))
    print("F1-Score: {}".format(best_score))

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train_resampled2, y_train_resampled2)
knn_preds = knn.predict(X_test2)
knn_f1 = metrics.f1_score(y_test2, knn_preds)
knn_acc = metrics.accuracy_score(y_test2, knn_preds)
print('Test F1 score: ', knn_f1)
print('Test Accuracy score: ', knn_acc)
# Out:
# Test F1 score:  0.3443708609271523
# Test Accuracy score:  0.9851995814023022

# %% [markdown]
# # Logistic Regression

# %%
lr = LogisticRegression(class_weight='balanced')
lr.fit(X_train2, y_train2)
lr_preds = lr.predict(X_test2)
lr_f1 = metrics.f1_score(y_test2, lr_preds)
lr_acc = metrics.accuracy_score(y_test2, lr_preds)
print('Test F1 score: ', lr_f1)
print('Test Accuracy score: ', lr_acc)
# Out:
# Test F1 score:  0.4035087719298246
# Test Accuracy score:  0.9796681118253849

# %% [markdown]
# # Decision Tree

# %%
SEED = 1
max_depths = np.linspace(1, 32, 32, endpoint=True)
train_results = []
test_results = []
for max_depth in max_depths:
   dt = DecisionTreeClassifier(criterion='entropy', max_depth=max_depth, random_state=SEED)
   dt.fit(X_train_resampled2, y_train_resampled2)
   train_pred = dt.predict(X_train_resampled2)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train_resampled2, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   # Add auc score to previous train results
   train_results.append(roc_auc)
   y_pred = dt.predict(X_test2)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   # Add auc score to previous test results
   test_results.append(roc_auc)
    
plt.figure(figsize=(12,6))
plt.plot(max_depths, train_results, 'b', label='Train AUC')
plt.plot(max_depths, test_results, 'r', label='Test AUC')
plt.ylabel('AUC score')
plt.xlabel('Tree depth')
plt.legend()
plt.show()

# %%
# Find the best value for optimal maximum feature size
max_features = list(range(1, X_train_resampled2.shape[1]))
train_results = []
test_results = []
for max_feature in max_features:
   dt = DecisionTreeClassifier(criterion='entropy', max_features=max_feature, random_state=SEED)
   dt.fit(X_train_resampled2, y_train_resampled2)
   train_pred = dt.predict(X_train_resampled2)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train_resampled2, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   train_results.append(roc_auc)
   y_pred = dt.predict(X_test2)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   test_results.append(roc_auc)

plt.figure(figsize=(12,6))
plt.plot(max_features, train_results, 'b', label='Train AUC')
plt.plot(max_features, test_results, 'r', label='Test AUC')
plt.ylabel('AUC score')
plt.xlabel('max features')
plt.legend()
plt.show()

# %%
dtc = DecisionTreeClassifier(criterion='entropy', max_depth=7, max_features=6, class_weight='balanced')
dtc.fit(X_train_resampled2, y_train_resampled2)
dtc_preds  = dtc.predict(X_test2)
dtc_f1 = metrics.f1_score(y_test2, dtc_preds)
dtc_acc = metrics.accuracy_score(y_test2, dtc_preds)
print('Test F1 score: ', dtc_f1)
print('Test Accuracy score: ', dtc_acc)
# Out:
# Test F1 score:  0.41628959276018107
# Test Accuracy score:  0.9807146060696667

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting_clf = VotingClassifier(
                estimators=[('knneighbors', knn), ('logreg', lr), ('decisiontree', dtc)], 
                voting='soft')
voting_clf.fit(X_train_resampled2, y_train_resampled2)
vc_preds = voting_clf.predict(X_test2)
vc_f1 = metrics.f1_score(y_test2, vc_preds)
vc_acc = metrics.accuracy_score(y_test2, vc_preds)
print('Test F1 score: ', vc_f1)
print('Test Accuracy score: ', vc_acc)
# Out:
# Test F1 score:  0.4230769230769231
# Test Accuracy score:  0.9820600986694573
